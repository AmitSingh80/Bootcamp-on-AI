# %%
import cv2
from ultralytics import settings

# Disable data and crash report tracking
settings.update({"sync": False})
from ultralytics import YOLO

# 1. Load the lightweight YOLOv8 Nano model (~6MB, runs fast on CPU)
model = YOLO('yolov8n.pt')

# 2. Open the webcam (0 is default built-in camera)
cap = cv2.VideoCapture(0)

print("Starting Object Counter... Press 'q' on the video window to quit.")

while cap.isOpened():
  success, frame = cap.read()
  if not success:
    print("Failed to grab camera frame.")
    break

  # 3. Perform object detection on the current frame
  results = model(frame, verbose=False)

  # Get total number of objects detected in this frame
  detected_count = len(results[0].boxes)

  # 4. Render detection boxes directly on the frame
  annotated_frame = results[0].plot()

  # 5. Display the object count overlay on screen
  cv2.putText(
      annotated_frame,
      f'Total Objects Counted: {detected_count}',
      (20, 50),  # Position (x, y)
      cv2.FONT_HERSHEY_SIMPLEX,
      1,  # Font scale
      (0, 255, 0),  # Text color (Green)
      2,  # Thickness
      cv2.LINE_AA,
  )

  # 6. Show the frame in a window
  cv2.imshow('BCA AI Demo - Live Object Counter', annotated_frame)

  # 7. Terminate program cleanly when pressing 'q'
  if cv2.waitKey(1) & 0xFF == ord('q'):
    print("Terminating program...")
    break

# Release camera and close all windows cleanly
cap.release()

# 2. Add short wait key loops to let Windows pump destroy events cleanly
cv2.waitKey(1)
cv2.destroyAllWindows()
cv2.waitKey(1)

print("Camera feed closed successfully.")
# Out:
# Starting Object Counter... Press 'q' on the video window to quit.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 23
#      19     print("Failed to grab camera frame.")
#      20     break
#      21
#      22   # 3. Perform object detection on the current frame
# ---> 23   results = model(frame, verbose=False)
#      24
#      25   # Get total number of objects detected in this frame
#      26   detected_count = len(results[0].boxes)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/engine/model.py:166, in Model.__call__(self, source, stream, **kwargs)
#     138 def __call__(
#     139     self,
#     140     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     141     stream: bool = False,
#     142     **kwargs: Any,
#     143 ) -> Iterator[Results | torch.Tensor] | list[Results] | list[torch.Tensor]:
#     144     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     145
#     146     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    164         ...     print(f"Detected {len(r)} objects in image")
#     165     """
# --> 166     return self.predict(source, stream, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/engine/model.py:558, in Model.predict(self, source, stream, predictor, **kwargs)
#     556 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     557     self.predictor.set_prompts(prompts)
# --> 558 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/engine/predictor.py:244, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     242     return self.stream_inference(source, model, *args, **kwargs)
#     243 else:
# --> 244     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/utils/_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/engine/predictor.py:357, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     355 # Inference
#     356 with profilers[1]:
# --> 357     preds = self.inference(im, *args, **kwargs)
#     358     if self.args.embed:
#     359         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/engine/predictor.py:201, in BasePredictor.inference(self, im, *args, **kwargs)
#     190 if self.args.visualize and getattr(self.model, "base_model", True) and not skip:
#     191     return class_activation_map(
#     192         self.model,
#     193         im,
#    (...)    199         **kwargs,
#     200     )
# --> 201 return self.model(im, *args, augment=self.args.augment, embed=self.args.embed, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/nn/autobackend.py:325, in AutoBackend.forward(self, im, augment, embed, **kwargs)
#     322 if self.format == "pt":
#     323     forward_kwargs = {"augment": augment, "embed": embed, **kwargs}
# --> 325 y = self.backend.forward(im, **forward_kwargs)
#     327 if isinstance(y, (list, tuple)):
#     328     if len(self.names) == 999 and (self.task == "segment" or len(y) == 2):  # segments and names not defined
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/nn/backends/pytorch.py:96, in PyTorchBackend.forward(self, im, augment, embed, **kwargs)
#      94 if not self.base_model:  # a foreign nn.Module defines no `augment`/`embed` contract to honor
#      95     return self.model(im, **kwargs)
# ---> 96 return self.model(im, augment=augment, embed=embed, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/nn/tasks.py:161, in BaseModel.forward(self, x, *args, **kwargs)
#     159 if isinstance(x, dict):  # for cases of training and validating while training.
#     160     return self.loss(x, *args, **kwargs)
# --> 161 return self.predict(x, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/nn/tasks.py:177, in BaseModel.predict(self, x, profile, augment, embed)
#     175 if augment:
#     176     return self._predict_augment(x)
# --> 177 return self._predict_once(x, profile, embed)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/nn/tasks.py:198, in BaseModel._predict_once(self, x, profile, embed)
#     196 if profile:
#     197     self._profile_one_layer(m, x, dt)
# --> 198 x = m(x)  # run
#     199 y.append(x if m.i in self.save else None)  # save output
#     200 if m.i in embed:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/nn/modules/block.py:315, in C2f.forward(self, x)
#     313 y = list(self.cv1(x).chunk(2, 1))
#     314 y.extend(m(y[-1]) for m in self.m)
# --> 315 return self.cv2(torch.cat(y, 1))
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ultralytics/nn/modules/conv.py:89, in Conv.forward_fuse(self, x)
#      80 def forward_fuse(self, x):
#      81     """Apply convolution and activation without batch normalization.
#      82
#      83     Args:
#    (...)     87         (torch.Tensor): Output tensor.
#      88     """
# ---> 89     return self.act(self.conv(x))
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/activation.py:476, in SiLU.forward(self, input)
#     472 def forward(self, input: Tensor) -> Tensor:
#     473     """
#     474     Runs the forward pass.
#     475     """
# --> 476     return F.silu(input, inplace=self.inplace)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/functional.py:2450, in silu(input, inplace)
#    2448     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2449 if inplace:
# -> 2450     return torch._C._nn.silu_(input)
#    2451 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pip install ultralytics opencv-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.161-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (5.0.0.93)
# Collecting cloudpickle>=3.1.1 (from ultralytics)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting filelock>=3.16.1 (from ultralytics)
#   Downloading filelock-4.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,!=2.3.1,!=2.3.2,!=2.3.3,!=2.3.4,>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (3.11.1)
# Requirement already satisfied: pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (12.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (2.34.2)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.14.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (39 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.29.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (5.7 kB)
# Requirement already satisfied: psutil>=5.8.0 in /Users/anish/Library/Python/3.14/lib/python/site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.44.2-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-ml-py>=12.0.0 (from ultralytics)
#   Downloading nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Collecting ultralytics-thop>=2.1.6 (from ultralytics)
#   Downloading ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# Collecting ultralytics-platform>=0.1.45 (from ultralytics)
#   Downloading ultralytics_platform-0.1.62-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/anish/Library/Python/3.14/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anish/Library/Python/3.14/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.44.2 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.44.2-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /Users/anish/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2026.7.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/anish/Library/Python/3.14/lib/python/site-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Collecting setuptools>=77.0.3 (from torch>=1.8.0->ultralytics)
#   Downloading setuptools-84.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.8.0->ultralytics)
#   Downloading networkx-3.7-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2026.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.8.0->ultralytics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: httpx<1,>=0.28 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics-platform>=0.1.45->ultralytics) (0.28.1)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.161-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.4 MB/s  0:00:01 eta 0:00:01
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading filelock-4.0.3-py3-none-any.whl (108 kB)
# Downloading nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# Downloading polars-1.44.2-py3-none-any.whl (865 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.8/865.8 kB 2.1 MB/s  0:00:00 eta 0:00:01
# Downloading polars_runtime_32-1.44.2-cp310-abi3-macosx_11_0_arm64.whl (43.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 MB 991.5 kB/s  0:00:44m0:00:01:020m
# Downloading torch-2.14.0-cp314-cp314-macosx_14_0_arm64.whl (127.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.3/127.3 MB 1.3 MB/s  0:01:55m0:00:0100:03m
# Downloading fsspec-2026.9.0-py3-none-any.whl (221 kB)
# Downloading networkx-3.7-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.8 MB/s  0:00:01 eta 0:00:01
# Downloading setuptools-84.0.0-py3-none-any.whl (818 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.2/818.2 kB 1.3 MB/s  0:00:00 eta 0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 2.2 MB/s  0:00:02 eta 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 3.4 MB/s  0:00:00
# Downloading torchvision-0.29.0-cp314-cp314-macosx_14_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.8 MB/s  0:00:00 eta 0:00:01
# Downloading ultralytics_platform-0.1.62-py3-none-any.whl (90 kB)
# Downloading ultralytics_thop-2.1.6-py3-none-any.whl (30 kB)
# Installing collected packages: nvidia-ml-py, mpmath, sympy, setuptools, polars-runtime-32, networkx, fsspec, filelock, cloudpickle, torch, polars, ultralytics-thop, ultralytics-platform, torchvision, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [ultralytics] [ultralytics]me-32]
# Successfully installed cloudpickle-3.1.2 filelock-4.0.3 fsspec-2026.9.0 mpmath-1.3.0 networkx-3.7 nvidia-ml-py-13.610.43 polars-1.44.2 polars-runtime-32-1.44.2 setuptools-84.0.0 sympy-1.14.0 torch-2.14.0 torchvision-0.29.0 ultralytics-8.4.161 ultralytics-platform-0.1.62 ultralytics-thop-2.1.6
# Note: you may need to restart the kernel to use updated packages.
